# %%
import yfinance as yf
import pandas_datareader as pdr
import pandas as pd
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt 
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
import itertools
import warnings
from matplotlib.pylab import rcParams
from statsmodels.tsa.stattools import kpss
from sklearn.metrics import mean_squared_error
from prophet import Prophet
import cufflinks as cf
from sklearn.metrics import mean_absolute_percentage_error
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Data Collection and Data Manipulation

# %%
def get_finance_data(stock):
    s = yf.Ticker(stock)
    
    df = s.history(start = '2009-01-31', end='2021-10-22', interval = "1d")
    df = df.drop(['Dividends', 'Stock Splits'], axis=1)

    return df

# %%
googl = get_finance_data('googl')

# %%
googl
# Out:
#                    Open         High          Low        Close    Volume
# Date
# 2009-02-02   167.312317   172.672668   166.166168   170.455460  10403386
# 2009-02-03   171.456451   171.671677   167.082077   170.395401  13099887
# 2009-02-04   170.205200   177.397400   169.754761   171.671677  13621165
# 2009-02-05   170.625626   177.867874   168.668671   177.037033  14514271
# 2009-02-06   178.408401   187.092087   177.897903   185.825821  14062124
# ...                 ...          ...          ...          ...       ...
# 2021-10-15  2832.290039  2834.360107  2815.100098  2827.360107   1512900
# 2021-10-18  2821.530029  2855.919922  2821.389893  2855.560059   1019800
# 2021-10-19  2867.750000  2873.250000  2852.000000  2864.739990   1008200
# 2021-10-20  2866.760010  2870.919922  2827.530029  2835.379883   1164400
# 2021-10-21  2835.379883  2843.120117  2810.000000  2837.719971   1314600
#
# [3204 rows x 5 columns]

# %%
googl_close = googl[['Close']]

# %% [markdown]
# ## Data Visualization

# %%
googl_close.iplot(title='Stock Close Prices', fill = True, xTitle='Dates',yTitle='Close Prices', theme='space')
# Out:
# <div>                            <div id="03848994-61c6-4682-a34a-3cf448206773" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("03848994-61c6-4682-a34a-3cf448206773")) {                    Plotly.newPlot(                        "03848994-61c6-4682-a34a-3cf448206773",                        [{"fill":"tozeroy","fillcolor":"rgba(255, 153, 51, 0.3)","line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Close","text":"","type":"scatter","x":["2009-02-02","2009-02-03","2009-02-04","2009-02-05","2009-02-06","2009-02-09","2009-02-10","2009-02-11","2009-02-12","2009-02-13","2009-02-17","2009-02-18","2009-02-19","2009-02-20","2009-02-23","2009-02-24","2009-02-25","2009-02-26","2009-02-27","2009-03-02","2009-03-03","2009-03-04","2009-03-05","2009-03-06","2009-03-09","2009-03-10","2009-03-11","2009-03-12","2009-03-13","2009-03-16","2009-03-17","2009-03-18","2009-03-19","2009-03-20","2009-03-23","2009-03-24","2009-03-25","2009-03-26","2009-03-27","2009-03-30","2009-03-31","2009-04-01","2009-04-02","2009-04-03","2009-04-06","2009-04-07","2009-04-08","2009-04-09","2009-04-13","2009-04-14","2009-04-15","2009-04-16","2009-04-17","2009-04-20","2009-04-21","2009-04-22","2009-04-23","2009-04-24","2009-04-27","2009-04-28","2009-04-29","2009-04-30","2009-05-01","2009-05-04","2009-05-05","2009-05-06","2009-05-07","2009-05-08","2009-05-11","2009-05-12","2009-05-13","2009-05-14","2009-05-15","2009-05-18","2009-05-19","2009-05-20","2009-05-21","2009-05-22","2009-05-26","2009-05-27","2009-05-28","2009-05-29","2009-06-01","2009-06-02","2009-06-03","2009-06-04","2009-06-05","2009-06-08","2009-06-09","2009-06-10","2009-06-11","2009-06-12","2009-06-15","2009-06-16","2009-06-17","2009-06-18","2009-06-19","2009-06-22","2009-06-23","2009-06-24","2009-06-25","2009-06-26","2009-06-29","2009-06-30","2009-07-01","2009-07-02","2009-07-06","2009-07-07","2009-07-08","2009-07-09","2009-07-10","2009-07-13","2009-07-14","2009-07-15","2009-07-16","2009-07-17","2009-07-20","2009-07-21","2009-07-22","2009-07-23","2009-07-24","2009-07-27","2009-07-28","2009-07-29","2009-07-30","2009-07-31","2009-08-03","2009-08-04","2009-08-05","2009-08-06","2009-08-07","2009-08-10","2009-08-11","2009-08-12","2009-08-13","2009-08-14","2009-08-17","2009-08-18","2009-08-19","2009-08-20","2009-08-21","2009-08-24","2009-08-25","2009-08-26","2009-08-27","2009-08-28","2009-08-31","2009-09-01","2009-09-02","2009-09-03","2009-09-04","2009-09-08","2009-09-09","2009-09-10","2009-09-11","2009-09-14","2009-09-15","2009-09-16","2009-09-17","2009-09-18","2009-09-21","2009-09-22","2009-09-23","2009-09-24","2009-09-25","2009-09-28","2009-09-29","2009-09-30","2009-10-01","2009-10-02","2009-10-05","2009-10-06","2009-10-07","2009-10-08","2009-10-09","2009-10-12","2009-10-13","2009-10-14","2009-10-15","2009-10-16","2009-10-19","2009-10-20","2009-10-21","2009-10-22","2009-10-23","2009-10-26","2009-10-27","2009-10-28","2009-10-29","2009-10-30","2009-11-02","2009-11-03","2009-11-04","2009-11-05","2009-11-06","2009-11-09","2009-11-10","2009-11-11","2009-11-12","2009-11-13","2009-11-16","2009-11-17","2009-11-18","2009-11-19","2009-11-20","2009-11-23","2009-11-24","2009-11-25","2009-11-27","2009-11-30","2009-12-01","2009-12-02","2009-12-03","2009-12-04","2009-12-07","2009-12-08","2009-12-09","2009-12-10","2009-12-11","2009-12-14","2009-12-15","2009-12-16","2009-12-17","2009-12-18","2009-12-21","2009-12-22","2009-12-23","2009-12-24","2009-12-28","2009-12-29","2009-12-30","2009-12-31","2010-01-04","2010-01-05","2010-01-06","2010-01-07","2010-01-08","2010-01-11","2010-01-12","2010-01-13","2010-01-14","2010-01-15","2010-01-19","2010-01-20","2010-01-21","2010-01-22","2010-01-25","2010-01-26","2010-01-27","2010-01-28","2010-01-29","2010-02-01","2010-02-02","2010-02-03","2010-02-04","2010-02-05","2010-02-08","2010-02-09","2010-02-10","2010-02-11","2010-02-12","2010-02-16","2010-02-17","2010-02-18","2010-02-19","2010-02-22","2010-02-23","2010-02-24","2010-02-25","2010 ...

# %%
googl['Volume'].iplot(title='Volume', xTitle='Dates', yTitle='Volume', theme='space')
# Out:
# <div>                            <div id="fa9de429-07d1-43a5-8182-5afcf0b6ea15" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("fa9de429-07d1-43a5-8182-5afcf0b6ea15")) {                    Plotly.newPlot(                        "fa9de429-07d1-43a5-8182-5afcf0b6ea15",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Volume","text":"","type":"scatter","x":["2009-02-02","2009-02-03","2009-02-04","2009-02-05","2009-02-06","2009-02-09","2009-02-10","2009-02-11","2009-02-12","2009-02-13","2009-02-17","2009-02-18","2009-02-19","2009-02-20","2009-02-23","2009-02-24","2009-02-25","2009-02-26","2009-02-27","2009-03-02","2009-03-03","2009-03-04","2009-03-05","2009-03-06","2009-03-09","2009-03-10","2009-03-11","2009-03-12","2009-03-13","2009-03-16","2009-03-17","2009-03-18","2009-03-19","2009-03-20","2009-03-23","2009-03-24","2009-03-25","2009-03-26","2009-03-27","2009-03-30","2009-03-31","2009-04-01","2009-04-02","2009-04-03","2009-04-06","2009-04-07","2009-04-08","2009-04-09","2009-04-13","2009-04-14","2009-04-15","2009-04-16","2009-04-17","2009-04-20","2009-04-21","2009-04-22","2009-04-23","2009-04-24","2009-04-27","2009-04-28","2009-04-29","2009-04-30","2009-05-01","2009-05-04","2009-05-05","2009-05-06","2009-05-07","2009-05-08","2009-05-11","2009-05-12","2009-05-13","2009-05-14","2009-05-15","2009-05-18","2009-05-19","2009-05-20","2009-05-21","2009-05-22","2009-05-26","2009-05-27","2009-05-28","2009-05-29","2009-06-01","2009-06-02","2009-06-03","2009-06-04","2009-06-05","2009-06-08","2009-06-09","2009-06-10","2009-06-11","2009-06-12","2009-06-15","2009-06-16","2009-06-17","2009-06-18","2009-06-19","2009-06-22","2009-06-23","2009-06-24","2009-06-25","2009-06-26","2009-06-29","2009-06-30","2009-07-01","2009-07-02","2009-07-06","2009-07-07","2009-07-08","2009-07-09","2009-07-10","2009-07-13","2009-07-14","2009-07-15","2009-07-16","2009-07-17","2009-07-20","2009-07-21","2009-07-22","2009-07-23","2009-07-24","2009-07-27","2009-07-28","2009-07-29","2009-07-30","2009-07-31","2009-08-03","2009-08-04","2009-08-05","2009-08-06","2009-08-07","2009-08-10","2009-08-11","2009-08-12","2009-08-13","2009-08-14","2009-08-17","2009-08-18","2009-08-19","2009-08-20","2009-08-21","2009-08-24","2009-08-25","2009-08-26","2009-08-27","2009-08-28","2009-08-31","2009-09-01","2009-09-02","2009-09-03","2009-09-04","2009-09-08","2009-09-09","2009-09-10","2009-09-11","2009-09-14","2009-09-15","2009-09-16","2009-09-17","2009-09-18","2009-09-21","2009-09-22","2009-09-23","2009-09-24","2009-09-25","2009-09-28","2009-09-29","2009-09-30","2009-10-01","2009-10-02","2009-10-05","2009-10-06","2009-10-07","2009-10-08","2009-10-09","2009-10-12","2009-10-13","2009-10-14","2009-10-15","2009-10-16","2009-10-19","2009-10-20","2009-10-21","2009-10-22","2009-10-23","2009-10-26","2009-10-27","2009-10-28","2009-10-29","2009-10-30","2009-11-02","2009-11-03","2009-11-04","2009-11-05","2009-11-06","2009-11-09","2009-11-10","2009-11-11","2009-11-12","2009-11-13","2009-11-16","2009-11-17","2009-11-18","2009-11-19","2009-11-20","2009-11-23","2009-11-24","2009-11-25","2009-11-27","2009-11-30","2009-12-01","2009-12-02","2009-12-03","2009-12-04","2009-12-07","2009-12-08","2009-12-09","2009-12-10","2009-12-11","2009-12-14","2009-12-15","2009-12-16","2009-12-17","2009-12-18","2009-12-21","2009-12-22","2009-12-23","2009-12-24","2009-12-28","2009-12-29","2009-12-30","2009-12-31","2010-01-04","2010-01-05","2010-01-06","2010-01-07","2010-01-08","2010-01-11","2010-01-12","2010-01-13","2010-01-14","2010-01-15","2010-01-19","2010-01-20","2010-01-21","2010-01-22","2010-01-25","2010-01-26","2010-01-27","2010-01-28","2010-01-29","2010-02-01","2010-02-02","2010-02-03","2010-02-04","2010-02-05","2010-02-08","2010-02-09","2010-02-10","2010-02-11","2010-02-12","2010-02-16","2010-02-17","2010-02-18","2010-02-19","2010-02-22","2010-02-23","2010-02-24","2010-02-25","2010-02-26","2010-03-01","2010-03-02","2010-03-03","2010-0 ...

# %%
#Test for staionarity
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    #Plot rolling statistics:
    plt.plot(timeseries, color='blue',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    
    print("Results of dickey fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)
    
test_stationarity(googl_close)
# Out:
# Results of dickey fuller test
# Test Statistics                   4.042390
# p-value                           1.000000
# No. of lags used                 26.000000
# Number of observations used    3177.000000
# critical value (1%)              -3.432410
# critical value (5%)              -2.862450
# critical value (10%)             -2.567255
# dtype: float64

# %%
result = seasonal_decompose(googl_close, model='multiplicative', period=30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %% [markdown]
# ## Modeling

# %%
googl_close
# Out:
#                   Close
# Date
# 2009-02-02   170.455460
# 2009-02-03   170.395401
# 2009-02-04   171.671677
# 2009-02-05   177.037033
# 2009-02-06   185.825821
# ...                 ...
# 2021-10-15  2827.360107
# 2021-10-18  2855.560059
# 2021-10-19  2864.739990
# 2021-10-20  2835.379883
# 2021-10-21  2837.719971
#
# [3204 rows x 1 columns]

# %% [markdown]
# ## ADF Test

# %% [markdown]
# Check for stationary series using the Augmented Dickey Fuller Test.
# The ADF test indicates whether or not differencing has to be done or not

# %%
from statsmodels.tsa.stattools import adfuller
from numpy import log
result = adfuller(googl_close.dropna())
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
# Out:
# ADF Statistic: 4.042390
# p-value: 1.000000

# %% [markdown]
# ## Differencing Term (d)

# %% [markdown]
# Since P-value is greater than the significance level, let’s difference the series and see how the autocorrelation plot looks like.

# %%
import numpy as np, pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt
plt.rcParams.update({'figure.figsize':(11,10), 'figure.dpi':120})

# Original Series
fig, axes = plt.subplots(3, 2)
axes[0, 0].plot(googl_close); axes[0, 0].set_title('Original Series')
plot_acf(googl_close, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(googl_close.diff()); axes[1, 0].set_title('1st Order Differencing')
plot_acf(googl_close.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(googl_close.diff().diff()); axes[2, 0].set_title('2nd Order Differencing')
plot_acf(googl_close.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %% [markdown]
# For the above series, the time series reaches stationarity with two orders of differencing. But on looking at the autocorrelation plot for the 2nd differencing the lag goes into the far negative zone fairly quick, which indicates, the series might have been over differenced

# %% [markdown]
# ## AR term (p)

# %%
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})

fig, axes = plt.subplots(1, 2)
axes[0].plot(googl_close.diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,5))
plot_pacf(googl_close.diff().dropna(), ax=axes[1])

plt.show()
# Out:
# C:\Users\ronak\Anaconda3\envs\capstone\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning:
#
# The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.

# %% [markdown]
# ACF lag 1 is quite significant since is well above the significance line, that is why the lag term will be closer to 1

# %% [markdown]
# ## MA Term (q)

# %%
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})


fig, axes = plt.subplots(1, 2)
axes[0].plot(googl_close.diff()); axes[0].set_title('1st Differencing')
axes[1].set(ylim=(0,1.2))
plot_acf(googl_close.diff().dropna(), ax=axes[1])

plt.show()

# %% [markdown]
# The 1st lag is well above the signifigance line so the q term will be set to 1

# %% [markdown]
# # ARIMA Model

# %% [markdown]
# ## Train-Test Split

# %%
n = int(len(googl_close) * 0.80)
train = googl_close[:n]
test = googl_close[n:]

# %%
train
# Out:
#                   Close
# Date
# 2009-02-02   170.455460
# 2009-02-03   170.395401
# 2009-02-04   171.671677
# 2009-02-05   177.037033
# 2009-02-06   185.825821
# ...                 ...
# 2019-04-02  1205.540039
# 2019-04-03  1210.810059
# 2019-04-04  1219.449951
# 2019-04-05  1211.449951
# 2019-04-08  1208.280029
#
# [2563 rows x 1 columns]

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')

# %% [markdown]
# ## Prediction

# %%
model = SARIMAX(googl_close, order=(1,1,1))
model_fit = model.fit()
print(model_fit.summary())
# Out:
# C:\Users\ronak\Anaconda3\envs\capstone\lib\site-packages\statsmodels\tsa\base\tsa_model.py:593: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#
# C:\Users\ronak\Anaconda3\envs\capstone\lib\site-packages\statsmodels\tsa\base\tsa_model.py:593: ValueWarning:
#
# A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 3204
# Model:               SARIMAX(1, 1, 1)   Log Likelihood              -13375.590
# Date:                Thu, 28 Oct 2021   AIC                          26757.181
# Time:                        08:28:06   BIC                          26775.396
# Sample:                             0   HQIC                         26763.711
#                                - 3204
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3233      0.092     -3.519      0.000      -0.503      -0.143
# ma.L1          0.2482      0.094      2.640      0.008       0.064       0.432
# sigma2       247.9966      2.236    110.889      0.000     243.613     252.380
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):             24918.07
# Prob(Q):                              0.85   Prob(JB):                         0.00
# Heteroskedasticity (H):              30.14   Skew:                             0.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                        16.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
pred = model_fit.predict(start=pd.to_datetime('2019-04-08'), dynamic=False)
plt.show()

# %%
rcParams['figure.figsize'] = 15, 6

# Plot observed values
ax = googl_close.plot(label='observed')

# Plot predicted values
pred.plot(ax=ax, label='One-step ahead Forecast', alpha=0.9)

# Plot the range for confidence intervals

# Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('Google Price')
plt.legend()

plt.show();

# %%
value_forecasted = pred
value_truth = googl_close['Close']['2019-04-08':]

# Compute the root mean square error
mse = ((value_forecasted - value_truth) ** 2).mean()
print('The Root Mean Squared Error of prediction is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of prediction is 29.53

# %%
mean_absolute_percentage_error(value_truth, value_forecasted)
# Out:
# 0.012820165352560857

# %% [markdown]
# # PMDARIMA

# %%
import pmdarima as pm
from pmdarima.arima import ndiffs
from pmdarima.metrics import smape

# %%
kpss_diffs = ndiffs(train, alpha=0.05, test='kpss', max_d=6)
adf_diffs = ndiffs(train, alpha=0.05, test='adf', max_d=6)
n_diffs = max(adf_diffs, kpss_diffs)

print(f"Estimated differencing term: {n_diffs}")
# Estimated differencing term: 1
# Out:
# Estimated differencing term: 1

# %%
auto = pm.auto_arima(train, d=n_diffs, seasonal=False, stepwise=True,
                     suppress_warnings=True, error_action="ignore", max_p=6,
                     max_order=None, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=inf, Time=2.83 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=18818.109, Time=0.08 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=18818.888, Time=0.19 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=18818.783, Time=0.33 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=18820.749, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=18817.139, Time=0.99 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=18818.235, Time=1.14 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=18818.262, Time=1.38 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=18816.575, Time=0.55 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=18818.357, Time=0.60 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=18811.492, Time=2.21 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=inf, Time=3.08 sec
#  ARIMA(1,1,4)(0,0,0)[0] intercept   : AIC=18808.170, Time=1.65 sec
#  ARIMA(0,1,4)(0,0,0)[0] intercept   : AIC=18819.143, Time=0.95 sec
#  ARIMA(2,1,4)(0,0,0)[0] intercept   : AIC=18809.760, Time=3.19 sec
#  ARIMA(1,1,5)(0,0,0)[0] intercept   : AIC=18808.317, Time=2.08 sec
#  ARIMA(0,1,5)(0,0,0)[0] intercept   : AIC=18812.690, Time=1.13 sec
#  ARIMA(2,1,5)(0,0,0)[0] intercept   : AIC=18803.339, Time=4.18 sec
#  ARIMA(3,1,5)(0,0,0)[0] intercept   : AIC=18787.221, Time=4.40 sec
#  ARIMA(3,1,4)(0,0,0)[0] intercept   : AIC=18784.935, Time=3.83 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=18784.106, Time=3.65 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=18800.182, Time=2.97 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : AIC=18790.130, Time=3.61 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : AIC=18806.617, Time=2.73 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : AIC=inf, Time=4.64 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : AIC=inf, Time=3.61 sec
#
# Best model:  ARIMA(3,1,3)(0,0,0)[0] intercept
# Total fit time: 56.092 seconds

# %%
print(auto.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2563
# Model:               SARIMAX(3, 1, 3)   Log Likelihood               -9384.053
# Date:                Thu, 28 Oct 2021   AIC                          18784.106
# Time:                        08:29:03   BIC                          18830.894
# Sample:                             0   HQIC                         18801.071
#                                - 2563
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0207      0.013      1.603      0.109      -0.005       0.046
# ar.L1          0.2023      0.014     14.039      0.000       0.174       0.231
# ar.L2         -0.2252      0.011    -20.257      0.000      -0.247      -0.203
# ar.L3          0.9707      0.014     68.748      0.000       0.943       0.998
# ma.L1         -0.1971      0.015    -13.093      0.000      -0.227      -0.168
# ma.L2          0.1956      0.012     16.711      0.000       0.173       0.219
# ma.L3         -0.9675      0.013    -73.594      0.000      -0.993      -0.942
# sigma2        88.4899      1.090     81.190      0.000      86.354      90.626
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.03   Jarque-Bera (JB):             13657.70
# Prob(Q):                              0.31   Prob(JB):                         0.00
# Heteroskedasticity (H):               8.66   Skew:                             0.17
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.31
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model = auto  # seeded from the model we've already fit

def forecast_one_step():
    fc, conf_int = model.predict(n_periods=1, return_conf_int=True)
    return (
        fc.tolist()[0],
        np.asarray(conf_int).tolist()[0])

forecasts = []
confidence_intervals = []

for new_ob in test['Close']:
    fc, conf = forecast_one_step()
    forecasts.append(fc)
    confidence_intervals.append(conf)

    # Updates the existing model with a small number of MLE steps
    model.update(new_ob)

print(f"Mean squared error: {mean_squared_error(test['Close'], forecasts)}")
print(f"SMAPE: {smape(test['Close'], forecasts)}")
# Out:
# Mean squared error: 895.8615733002913
# SMAPE: 1.3050697623310714

# %%
ax = googl_close.iloc[1500:].plot(label='observed', figsize=(20, 15))
ax.plot(train, color='blue', label='Training Data')
ax.plot(test.index, forecasts, color='green', marker='o',
             label='Predicted Price')
ax.plot(test.index, test, color='red', marker='o', label='Predicted Price')
ax.set_xlabel('Dates')
ax.set_ylabel('Prices')
#axes[0].plot(test_data.index, forecasts, color='green', marker='o',
       #      label='Predicted Price')

plt.legend()
plt.show()

# %%
print('The Root Mean Squared Error of prediction is {}'.format(round(np.sqrt(895.8615733002913), 2)))
# Out:
# The Root Mean Squared Error of prediction is 29.93

# %% [markdown]
# ## SARIMAX PMDARIMA

# %%
smodel = pm.auto_arima(train, start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, m=12,
                         start_P=0, seasonal=True,
                         d=None, D=1, trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,1,1)[12] intercept   : AIC=inf, Time=5.85 sec
#  ARIMA(0,0,0)(0,1,0)[12] intercept   : AIC=24569.315, Time=0.14 sec
#  ARIMA(1,0,0)(1,1,0)[12] intercept   : AIC=19755.768, Time=2.46 sec
#  ARIMA(0,0,1)(0,1,1)[12] intercept   : AIC=22276.204, Time=3.13 sec
#  ARIMA(0,0,0)(0,1,0)[12]             : AIC=24632.468, Time=0.10 sec
#  ARIMA(1,0,0)(0,1,0)[12] intercept   : AIC=20398.173, Time=0.43 sec
#  ARIMA(1,0,0)(2,1,0)[12] intercept   : AIC=19376.427, Time=9.46 sec
#  ARIMA(1,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=17.58 sec
#  ARIMA(1,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=5.04 sec
#  ARIMA(0,0,0)(2,1,0)[12] intercept   : AIC=24537.178, Time=9.32 sec
#  ARIMA(2,0,0)(2,1,0)[12] intercept   : AIC=19370.574, Time=18.97 sec
#  ARIMA(2,0,0)(1,1,0)[12] intercept   : AIC=19750.589, Time=4.87 sec
#  ARIMA(2,0,0)(2,1,1)[12] intercept   : AIC=inf, Time=27.70 sec
#  ARIMA(2,0,0)(1,1,1)[12] intercept   : AIC=inf, Time=11.12 sec
#  ARIMA(3,0,0)(2,1,0)[12] intercept   : AIC=19372.532, Time=20.37 sec
#  ARIMA(2,0,1)(2,1,0)[12] intercept   : AIC=19372.681, Time=20.60 sec
#  ARIMA(1,0,1)(2,1,0)[12] intercept   : AIC=19370.632, Time=14.55 sec
#  ARIMA(3,0,1)(2,1,0)[12] intercept   : AIC=19374.310, Time=25.35 sec
#  ARIMA(2,0,0)(2,1,0)[12]             : AIC=19373.869, Time=4.29 sec
#
# Best model:  ARIMA(2,0,0)(2,1,0)[12] intercept
# Total fit time: 201.377 seconds

# %%
model = smodel  # seeded from the model we've already fit

def forecast_one_step():
    fc, conf_int = model.predict(n_periods=1, return_conf_int=True)
    return (
        fc.tolist()[0],
        np.asarray(conf_int).tolist()[0])

forecasts = []
confidence_intervals = []

for new_ob in test['Close']:
    fc, conf = forecast_one_step()
    forecasts.append(fc)
    confidence_intervals.append(conf)

    # Updates the existing model with a small number of MLE steps
    model.update(new_ob)

print(f"Mean squared error: {mean_squared_error(test['Close'], forecasts)}")
print(f"SMAPE: {smape(test['Close'], forecasts)}")
# Out:
# Mean squared error: 1167.7160854327344
# SMAPE: 1.5224362444073194

# %%
ax = googl_close.iloc[1500:].plot(label='observed', figsize=(20, 15))
ax.plot(train, color='blue', label='Training Data')
ax.plot(test.index, forecasts, color='green', marker='o',
             label='Predicted Price')
ax.plot(test.index, test, color='red', marker='o', label='Predicted Price')
ax.set_xlabel('Dates')
ax.set_ylabel('Prices')
#axes[0].plot(test_data.index, forecasts, color='green', marker='o',
       #      label='Predicted Price')

plt.legend()
plt.show()

# %%
print('The Root Mean Squared Error of prediction is {}'.format(round(np.sqrt(1167.7160854327344), 2)))
# Out:
# The Root Mean Squared Error of prediction is 34.17

# %% [markdown]
# ## FBPROPHET

# %%
googl_close = googl[['Close']]

# %%
googl = googl_close.reset_index()

# %%
googl
# Out:
#            Date        Close
# 0    2009-02-02   170.455460
# 1    2009-02-03   170.395401
# 2    2009-02-04   171.671677
# 3    2009-02-05   177.037033
# 4    2009-02-06   185.825821
# ...         ...          ...
# 3199 2021-10-15  2827.360107
# 3200 2021-10-18  2855.560059
# 3201 2021-10-19  2864.739990
# 3202 2021-10-20  2835.379883
# 3203 2021-10-21  2837.719971
#
# [3204 rows x 2 columns]

# %%
googl.rename(columns={'Close': 'y', 'Date': 'ds'},inplace=True)
googl['ds'] = pd.to_datetime(googl['ds'])
googl['y']=googl['y'].astype(float)

# %%
df_prophet = Prophet(changepoint_prior_scale=0.15, daily_seasonality=False)
df_prophet.fit(googl)

# %%
fcast_time=365   # 1 year
df_forecast = df_prophet.make_future_dataframe(periods= fcast_time, freq='D')
df_forecast.tail(10)
# Out:
#              ds
# 3559 2022-10-12
# 3560 2022-10-13
# 3561 2022-10-14
# 3562 2022-10-15
# 3563 2022-10-16
# 3564 2022-10-17
# 3565 2022-10-18
# 3566 2022-10-19
# 3567 2022-10-20
# 3568 2022-10-21

# %%
# Forecasting - call the method predict
df_forecast = df_prophet.predict(df_forecast)
# Out:
#   0%|          | 0/18 [01:43<?, ?it/s]

# %%
df_forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds         yhat   yhat_lower   yhat_upper
# 3564 2022-10-17  3116.693003  2900.108749  3305.570522
# 3565 2022-10-18  3118.932386  2922.601206  3310.824957
# 3566 2022-10-19  3121.422677  2907.929586  3308.800411
# 3567 2022-10-20  3122.967190  2909.028342  3307.500805
# 3568 2022-10-21  3124.652094  2924.779290  3312.252381

# %%
df_prophet.plot(df_forecast, xlabel = 'Date', ylabel = 'Apple Price');

# %%
fig2 = df_prophet.plot_components(df_forecast)
plt.show()

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(df_prophet, horizon = '365 days')
# Out:
# INFO:prophet:Making 18 forecasts with cutoffs between 2012-04-23 12:00:00 and 2020-10-21 00:00:00
# 100%|██████████| 18/18 [05:11<00:00, 17.30s/it]

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#            horizon          mse       rmse        mae      mape     mdape  \
# 0 36 days 12:00:00  9533.165887  97.637933  75.797365  0.090627  0.072958
# 1 37 days 00:00:00  9829.981433  99.146263  77.020776  0.091802  0.074361
# 2 37 days 12:00:00  9874.757259  99.371813  77.207000  0.091714  0.073616
# 3 38 days 00:00:00  9988.573809  99.942853  77.942245  0.092662  0.074361
# 4 38 days 12:00:00  9974.728530  99.873563  77.891361  0.092563  0.074087
#
#       smape  coverage
# 0  0.090194  0.173831
# 1  0.091358  0.168142
# 2  0.091337  0.166561
# 3  0.092301  0.161188
# 4  0.092241  0.159924

# %% [markdown]
# ## Result
#
# The ARIMA model performed the best with the lowest rmse
